# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('covid-Copy.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_csv('covid-Copy.csv')
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df.head()

# %%
df.info()

# %%
df.isnull()

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
df.rooms.median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.rooms.median()
#
# NameError: name 'df' is not defined

# %%
df.rooms=df.rooms.fillna(df.rooms.median())
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.rooms=df.rooms.fillna(df.rooms.median())
#       2 df
#
# NameError: name 'df' is not defined

# %%
reg = linear_model.LinearRegression()
reg.fit(df.drop('price',axis='columns'),df.price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 reg = linear_model.LinearRegression()
# ----> 2 reg.fit(df.drop('price',axis='columns'),df.price)
#
# NameError: name 'df' is not defined

# %%
from sklearn.metrics import r2_score

# Predict the prices using the trained model
predicted_prices = reg.predict(df.drop('price', axis='columns'))

# Calculate the R-squared value
r2 = r2_score(df['price'], predicted_prices)
print(f'R-squared (R²) value: {r2:.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 from sklearn.metrics import r2_score
#       3 # Predict the prices using the trained model
# ----> 4 predicted_prices = reg.predict(df.drop('price', axis='columns'))
#       6 # Calculate the R-squared value
#       7 r2 = r2_score(df['price'], predicted_prices)
#
# NameError: name 'df' is not defined

# %%
reg.predict([[4200,6.0,8]])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 reg.predict([[4200,6.0,8]])
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:275, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
# --> 275     check_is_fitted(self)
#     277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1754, in check_is_fitted(estimator, attributes, msg, all_or_any)
# ...

# %%
reg.coef_

# %%
reg.intercept_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 reg.intercept_
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
112.06244194*6500+ 23388.88007794*5 + -3231.71790863*45 + 221323.00186540384
# Out:
# 921245.9689767538

# %%
import matplotlib.pyplot as plt

plt.scatter(df['area'],df['price'],color='red',label='dot')
plt.plot(df['area'],df['price'],label='line')
plt.title('graph')
plt.legend()
plt.xlabel('area')
plt.ylabel('price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.scatter(df['area'],df['price'],color='red',label='dot')
#       4 plt.plot(df['area'],df['price'],label='line')
#       5 plt.title('graph')
#
# NameError: name 'df' is not defined

# %%
plt.bar(df['rooms'],df['price'],color=['red','blue','pink','orange'])
plt.show()
